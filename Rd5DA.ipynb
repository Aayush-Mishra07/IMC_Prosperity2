# %%
import numpy as np
import pandas as pd

# %%
rd1day_1 = pd.read_csv("/Users/aayushmishra/Desktop/IMCProsperity/Data/round-5-island-data-bottle/trades_round_1_day_-1_wn.csv",delimiter = ';')
rd1day_2 = pd.read_csv("/Users/aayushmishra/Desktop/IMCProsperity/Data/round-5-island-data-bottle/trades_round_1_day_-2_wn.csv",delimiter = ';')
rd1day0 = pd.read_csv("/Users/aayushmishra/Desktop/IMCProsperity/Data/round-5-island-data-bottle/trades_round_1_day_0_wn.csv",delimiter = ';')
rd2day0 = pd.read_csv("/Users/aayushmishra/Desktop/IMCProsperity/Data/round-5-island-data-bottle/trades_round_3_day_0_wn.csv",delimiter = ';')
rd2day1 = pd.read_csv("/Users/aayushmishra/Desktop/IMCProsperity/Data/round-5-island-data-bottle/trades_round_3_day_1_wn.csv",delimiter = ';')
rd2day2 = pd.read_csv("/Users/aayushmishra/Desktop/IMCProsperity/Data/round-5-island-data-bottle/trades_round_3_day_2_wn.csv",delimiter = ';')
rd3day_1 = pd.read_csv("/Users/aayushmishra/Desktop/IMCProsperity/Data/round-5-island-data-bottle/trades_round_4_day_1_wn.csv",delimiter = ';')
rd3day2 = pd.read_csv("/Users/aayushmishra/Desktop/IMCProsperity/Data/round-5-island-data-bottle/trades_round_4_day_2_wn.csv",delimiter = ';')
rd3day3 = pd.read_csv("/Users/aayushmishra/Desktop/IMCProsperity/Data/round-5-island-data-bottle/trades_round_4_day_3_wn.csv",delimiter = ';')
tradesall = pd.concat([rd1day_1,rd1day_2,rd1day0,rd2day0,rd2day1,rd2day2,rd3day_1,rd3day2,rd3day3], ignore_index=True)

# %%
tradesall.head(20)
# Out:
#     timestamp      buyer     seller     symbol   currency    price  quantity
# 0           0     Amelia  Valentina  STARFRUIT  SEASHELLS   5047.0        13
# 1           0       Remy  Valentina  STARFRUIT  SEASHELLS   5047.0         1
# 2           0       Remy     Vinnie  AMETHYSTS  SEASHELLS  10004.0         1
# 3        1100     Vinnie     Amelia  AMETHYSTS  SEASHELLS   9996.0         2
# 4        1700       Remy   Vladimir  AMETHYSTS  SEASHELLS  10002.0         1
# 5        1700       Ruby   Vladimir  STARFRUIT  SEASHELLS   5043.0         8
# 6        1800       Remy  Valentina  AMETHYSTS  SEASHELLS  10002.0         1
# 7        1900       Remy   Vladimir  STARFRUIT  SEASHELLS   5044.0         1
# 8        2000  Valentina       Remy  AMETHYSTS  SEASHELLS   9998.0         1
# 9        2400  Valentina       Remy  STARFRUIT  SEASHELLS   5038.0         1
# 10       2900     Vinnie     Amelia  AMETHYSTS  SEASHELLS   9996.0         1
# ...

# %%
tradesall['buyer'].value_counts()
# Out:
# Vinnie       9648
# Remy         8620
# Valentina    7488
# Vladimir     2227
# Ruby         1760
# Rhianna      1694
# Amelia        641
# Adam          363
# Raj           210
# Name: buyer, dtype: int64

# %%
tradesall['seller'].value_counts()
# Out:
# Remy         9164
# Vinnie       8915
# Valentina    5044
# Vladimir     3927
# Rhianna      2396
# Ruby         1964
# Amelia        627
# Adam          393
# Raj           221
# Name: seller, dtype: int64

# %%
Starfruit_trades = tradesall[tradesall['symbol'] == "STARFRUIT"]
Amethyst_trades = tradesall[tradesall['symbol'] == "AMETHYSTS"]
Giftbasket_trades = tradesall[tradesall['symbol'] == "GIFT_BASKET"]
Chocolate_trades = tradesall[tradesall['symbol'] == "CHOCOLATE"]
Strawberries_trades = tradesall[tradesall['symbol'] == "STRAWBERRIES"]
Rose_trades = tradesall[tradesall['symbol'] == "ROSES"]
Coconut_trades = tradesall[tradesall['symbol'] == "COCONUT"]
Coupon_trades = tradesall[tradesall['symbol'] == "COCONUT_COUPON"]

# %%
Coupon_trades['buyer'].value_counts()
# Out:
# Valentina    2531
# Ruby          380
# Vladimir      214
# Vinnie         25
# Rhianna        10
# Name: buyer, dtype: int64

# %%
Coupon_trades['seller'].value_counts()
# Out:
# Vinnie       1623
# Valentina     671
# Ruby          439
# Rhianna       388
# Vladimir       39
# Name: seller, dtype: int64

# %%
Coconut_trades['buyer'].value_counts()
# Out:
# Vinnie     1578
# Raj         210
# Rhianna     181
# Name: buyer, dtype: int64

# %%
Coconut_trades['seller'].value_counts()
# Out:
# Vinnie     1551
# Raj         221
# Rhianna     197
# Name: seller, dtype: int64

# %%
Giftbasket_trades['buyer'].value_counts()
# Out:
# Vinnie      558
# Vladimir    464
# Ruby        385
# Rhianna     358
# Name: buyer, dtype: int64

# %%
Giftbasket_trades['seller'].value_counts()
# Out:
# Rhianna     592
# Vinnie      486
# Ruby        403
# Vladimir    284
# Name: seller, dtype: int64

# %%
Chocolate_trades['buyer'].value_counts()
# Out:
# Vinnie      1768
# Remy        1077
# Vladimir       3
# Name: buyer, dtype: int64

# %%
Chocolate_trades['seller'].value_counts()
# Out:
# Remy        1188
# Vinnie      1071
# Vladimir     589
# Name: seller, dtype: int64

# %%
Strawberries_trades['buyer'].value_counts()
# Out:
# Vinnie      2400
# Remy        1247
# Vladimir       7
# Name: buyer, dtype: int64

# %%
Strawberries_trades['seller'].value_counts()
# Out:
# Vinnie      1234
# Remy        1228
# Vladimir    1192
# Name: seller, dtype: int64

# %%
Rose_trades['buyer'].value_counts()
# Out:
# Vinnie      1687
# Remy        1413
# Rhianna        3
# Vladimir       2
# Name: buyer, dtype: int64

# %%
Rose_trades['seller'].value_counts()
# Out:
# Vinnie      1415
# Remy        1376
# Vladimir     311
# Rhianna        3
# Name: seller, dtype: int64

# %%
Amethyst_trades['buyer'].value_counts()
# Out:
# Remy         2197
# Valentina    1739
# Vinnie        949
# Vladimir      753
# Rhianna       655
# Ruby          509
# Amelia        302
# Adam          131
# Name: buyer, dtype: int64

# %%
Amethyst_trades['seller'].value_counts()
# Out:
# Remy         2182
# Valentina    1725
# Vinnie        906
# Vladimir      697
# Rhianna       677
# Ruby          604
# Amelia        302
# Adam          142
# Name: seller, dtype: int64

# %%
Starfruit_trades['buyer'].value_counts()
# Out:
# Valentina    3218
# Remy         2686
# Vladimir      784
# Vinnie        683
# Rhianna       487
# Ruby          486
# Amelia        339
# Adam          232
# Name: buyer, dtype: int64

# %%
Starfruit_trades['seller'].value_counts()
# Out:
# Remy         3190
# Valentina    2648
# Vladimir      815
# Vinnie        629
# Rhianna       539
# Ruby          518
# Amelia        325
# Adam          251
# Name: seller, dtype: int64

# %%
tradesall.sort_values(by='quantity', ascending=False).head(60)
# Out:
#        timestamp      buyer     seller          symbol   currency  price  \
# 31971     580800  Valentina       Ruby  COCONUT_COUPON  SEASHELLS  536.0
# 28807     749600  Valentina     Vinnie  COCONUT_COUPON  SEASHELLS  671.0
# 30062     458500  Valentina     Vinnie  COCONUT_COUPON  SEASHELLS  657.0
# 32229     734800  Valentina     Vinnie  COCONUT_COUPON  SEASHELLS  581.0
# 27711      99700  Valentina     Vinnie  COCONUT_COUPON  SEASHELLS  592.0
# 32213     725100  Valentina       Ruby  COCONUT_COUPON  SEASHELLS  584.0
# 28322     452200  Valentina     Vinnie  COCONUT_COUPON  SEASHELLS  677.0
# 28323     452200       Ruby  Valentina  COCONUT_COUPON  SEASHELLS  678.0
# 30821     933300  Valentina       Ruby  COCONUT_COUPON  SEASHELLS  663.0
# 32203     719900  Valentina     Vinnie  COCONUT_COUPON  SEASHELLS  583.0
# 30798     921800       Ruby  Valentina  COCONUT_COUPON  SEASHELLS  657.0
# 28799     746000  Valentina       Ruby  COCONUT_COUPON  SEASHELLS  658.0
# ...

# %%
tradesall[tradesall["buyer"]=="Valentina"].sort_values(by ="quantity",ascending = False).head(50)
# Out:
#        timestamp      buyer  seller          symbol   currency  price  \
# 30640     809500  Valentina  Vinnie  COCONUT_COUPON  SEASHELLS  638.0
# 30352     625600  Valentina  Vinnie  COCONUT_COUPON  SEASHELLS  643.0
# 28322     452200  Valentina  Vinnie  COCONUT_COUPON  SEASHELLS  677.0
# 29238       3500  Valentina  Vinnie  COCONUT_COUPON  SEASHELLS  677.0
# 32504     907100  Valentina  Vinnie  COCONUT_COUPON  SEASHELLS  560.0
# 31564     344100  Valentina  Vinnie  COCONUT_COUPON  SEASHELLS  590.0
# 30506     723200  Valentina    Ruby  COCONUT_COUPON  SEASHELLS  648.0
# 32083     637500  Valentina  Vinnie  COCONUT_COUPON  SEASHELLS  563.0
# 29171     958800  Valentina  Vinnie  COCONUT_COUPON  SEASHELLS  681.0
# 31560     340100  Valentina    Ruby  COCONUT_COUPON  SEASHELLS  595.0
# 29143     947300  Valentina  Vinnie  COCONUT_COUPON  SEASHELLS  684.0
# 31550     334500  Valentina  Vinnie  COCONUT_COUPON  SEASHELLS  598.0
# ...

# %%
tradesall[tradesall["symbol"]=="GIFT_BASKET"].sort_values(by ="quantity",ascending = False).head(50)
# Out:
#        timestamp     buyer    seller       symbol   currency    price  \
# 19133     777300      Ruby  Vladimir  GIFT_BASKET  SEASHELLS  71118.0
# 23511     943100      Ruby  Vladimir  GIFT_BASKET  SEASHELLS  70761.0
# 16852     187800      Ruby  Vladimir  GIFT_BASKET  SEASHELLS  71372.0
# 22047     561300      Ruby  Vladimir  GIFT_BASKET  SEASHELLS  71034.0
# 16343      48400  Vladimir      Ruby  GIFT_BASKET  SEASHELLS  71438.0
# 22088     573900      Ruby  Vladimir  GIFT_BASKET  SEASHELLS  71073.0
# 25358     416700  Vladimir      Ruby  GIFT_BASKET  SEASHELLS  69820.0
# 22358     640900  Vladimir      Ruby  GIFT_BASKET  SEASHELLS  70733.0
# 22371     645300      Ruby  Vladimir  GIFT_BASKET  SEASHELLS  70769.0
# 23089     830700  Vladimir      Ruby  GIFT_BASKET  SEASHELLS  70805.0
# 26560     746000      Ruby  Vladimir  GIFT_BASKET  SEASHELLS  70024.0
# 17613     384200      Ruby  Vladimir  GIFT_BASKET  SEASHELLS  71259.0
# ...

# %%
tradesall[tradesall["symbol"]=="STARFRUIT"].sort_values(by ="quantity",ascending = False).head(50)
# Out:
#        timestamp      buyer     seller     symbol   currency   price  quantity
# 13055     404700     Amelia  Valentina  STARFRUIT  SEASHELLS  5061.0        15
# 10903      12000    Rhianna  Valentina  STARFRUIT  SEASHELLS  5032.0        15
# 1550      286300  Valentina       Ruby  STARFRUIT  SEASHELLS  5028.0        15
# 7083      327000  Valentina     Amelia  STARFRUIT  SEASHELLS  4963.0        15
# 7063      323200     Amelia  Valentina  STARFRUIT  SEASHELLS  4966.0        15
# 12020     207800     Amelia  Valentina  STARFRUIT  SEASHELLS  5051.0        15
# 13317     452100  Valentina       Ruby  STARFRUIT  SEASHELLS  5053.0        15
# 14854     745600  Valentina       Ruby  STARFRUIT  SEASHELLS  5057.0        15
# 15286     829300     Amelia  Valentina  STARFRUIT  SEASHELLS  5090.0        15
# 3530      662200       Ruby  Valentina  STARFRUIT  SEASHELLS  5070.0        15
# 13689     521800       Ruby  Valentina  STARFRUIT  SEASHELLS  5070.0        15
# ...

# %%
tradesall[tradesall["symbol"]=="CHOCOLATE"].sort_values(by ="quantity",ascending = False).head(50)
# Out:
#        timestamp   buyer    seller     symbol   currency   price  quantity
# 21890     513000  Vinnie  Vladimir  CHOCOLATE  SEASHELLS  7936.0        10
# 24210     124300  Vinnie  Vladimir  CHOCOLATE  SEASHELLS  7897.0        10
# 25016     330900  Vinnie  Vladimir  CHOCOLATE  SEASHELLS  7763.0        10
# 17042     239200  Vinnie  Vladimir  CHOCOLATE  SEASHELLS  7994.0        10
# 24889     302200  Vinnie  Vladimir  CHOCOLATE  SEASHELLS  7771.0        10
# 17137     264100  Vinnie  Vladimir  CHOCOLATE  SEASHELLS  7981.0        10
# 24533     207200  Vinnie  Vladimir  CHOCOLATE  SEASHELLS  7850.0        10
# 24399     171900  Vinnie  Vladimir  CHOCOLATE  SEASHELLS  7873.0        10
# 24219     127300  Vinnie  Vladimir  CHOCOLATE  SEASHELLS  7898.0        10
# 24202     120900  Vinnie  Vladimir  CHOCOLATE  SEASHELLS  7907.0        10
# 25345     413900  Vinnie  Vladimir  CHOCOLATE  SEASHELLS  7783.0        10
# ...

# %%
tradesall[tradesall["symbol"]=="ROSES"].sort_values(by ="quantity",ascending = False).head(50)
# Out:
#        timestamp   buyer    seller symbol   currency    price  quantity
# 24835     287800  Vinnie  Vladimir  ROSES  SEASHELLS  14327.0        11
# 16711     149700  Vinnie  Vladimir  ROSES  SEASHELLS  14747.0        11
# 25049     337900  Vinnie  Vladimir  ROSES  SEASHELLS  14295.0        11
# 27452     980400  Vinnie  Vladimir  ROSES  SEASHELLS  14336.0        11
# 20612     166000  Vinnie  Vladimir  ROSES  SEASHELLS  14537.0        11
# 18437     588700  Vinnie  Vladimir  ROSES  SEASHELLS  14687.0        11
# 23378     910300  Vinnie  Vladimir  ROSES  SEASHELLS  14440.0        11
# 23362     906300  Vinnie  Vladimir  ROSES  SEASHELLS  14441.0        11
# 27077     882800  Vinnie  Vladimir  ROSES  SEASHELLS  14296.0        11
# 22481     672100  Vinnie  Vladimir  ROSES  SEASHELLS  14532.0        11
# 25075     345000  Vinnie  Vladimir  ROSES  SEASHELLS  14260.0        11
# 25769     529000  Vinnie  Vladimir  ROSES  SEASHELLS  14250.0        11
# ...

# %%
tradesall[tradesall["symbol"]=="STRAWBERRIES"].sort_values(by ="quantity",ascending = False).head(50)
# Out:
#        timestamp   buyer    seller        symbol   currency   price  quantity
# 18501     604500  Vinnie  Vladimir  STRAWBERRIES  SEASHELLS  4036.0        12
# 21514     412600  Vinnie  Vladimir  STRAWBERRIES  SEASHELLS  4060.0        12
# 21113     304600  Vinnie  Vladimir  STRAWBERRIES  SEASHELLS  4039.0        12
# 21156     314400  Vinnie  Vladimir  STRAWBERRIES  SEASHELLS  4042.0        12
# 18640     643500  Vinnie  Vladimir  STRAWBERRIES  SEASHELLS  4049.0        12
# 21328     359300  Vinnie  Vladimir  STRAWBERRIES  SEASHELLS  4050.0        12
# 25749     525000  Vinnie  Vladimir  STRAWBERRIES  SEASHELLS  4007.0        12
# 21355     367400  Vinnie  Vladimir  STRAWBERRIES  SEASHELLS  4056.0        12
# 21397     379600  Vinnie  Vladimir  STRAWBERRIES  SEASHELLS  4058.0        12
# 21483     403500  Vinnie  Vladimir  STRAWBERRIES  SEASHELLS  4058.0        12
# 21645     450900  Vinnie  Vladimir  STRAWBERRIES  SEASHELLS  4059.0        12
# ...
