# %%
import pandas as pd
import numpy as np

# %%
prices1 = pd.read_csv("/Users/aayushmishra/Desktop/IMCProsperity/Data/round-4-island-data-bottle/prices_round_4_day_1.csv",delimiter = ';')
prices2 = pd.read_csv("/Users/aayushmishra/Desktop/IMCProsperity/Data/round-4-island-data-bottle/prices_round_4_day_2.csv",delimiter = ';')
prices3 = pd.read_csv("/Users/aayushmishra/Desktop/IMCProsperity/Data/round-4-island-data-bottle/prices_round_4_day_3.csv",delimiter = ';')
trades1 = pd.read_csv("/Users/aayushmishra/Desktop/IMCProsperity/Data/round-4-island-data-bottle/trades_round_4_day_1_nn.csv",delimiter = ';')
trades2 = pd.read_csv("/Users/aayushmishra/Desktop/IMCProsperity/Data/round-4-island-data-bottle/trades_round_4_day_2_nn.csv",delimiter = ';')
trades3 = pd.read_csv("/Users/aayushmishra/Desktop/IMCProsperity/Data/round-4-island-data-bottle/trades_round_4_day_3_nn.csv",delimiter = ';')
pricesall = pd.concat([prices1,prices2,prices3], ignore_index=True)
tradesall = pd.concat([trades1,trades2,trades3], ignore_index=True)

# %%
prices1
# Out:
#        day  timestamp         product  bid_price_1  bid_volume_1  bid_price_2  \
# 0        1          0         COCONUT         9999           200          NaN
# 1        1          0  COCONUT_COUPON          637            39          NaN
# 2        1        100         COCONUT         9999           104       9998.0
# 3        1        100  COCONUT_COUPON          637            33          NaN
# 4        1        200         COCONUT         9998           133       9997.0
# ...    ...        ...             ...          ...           ...          ...
# 19995    1     999700  COCONUT_COUPON          681            46          NaN
# 19996    1     999800  COCONUT_COUPON          681            43          NaN
# 19997    1     999800         COCONUT        10134           122      10133.0
# 19998    1     999900  COCONUT_COUPON          682            36          NaN
# 19999    1     999900         COCONUT        10134           178          NaN
#
# ...

# %%
prices1.head(20)
# Out:
#     day  timestamp         product  bid_price_1  bid_volume_1  bid_price_2  \
# 0     1          0         COCONUT         9999           200          NaN
# 1     1          0  COCONUT_COUPON          637            39          NaN
# 2     1        100         COCONUT         9999           104       9998.0
# 3     1        100  COCONUT_COUPON          637            33          NaN
# 4     1        200         COCONUT         9998           133       9997.0
# 5     1        200  COCONUT_COUPON          637            42          NaN
# 6     1        300  COCONUT_COUPON          638            30          NaN
# 7     1        300         COCONUT         9999           149       9998.0
# 8     1        400         COCONUT         9998           108       9997.0
# 9     1        400  COCONUT_COUPON          637            33          NaN
# 10    1        500         COCONUT         9996           114       9995.0
# ...

# %%
prices1['bid_price_2'].isna().sum()
# Out:
# 12136

# %%
cocoprices = pricesall[pricesall['product']=='COCONUT']
couponprices = pricesall[pricesall['product']=='COCONUT_COUPON']
columns_to_keep = ['timestamp', 'mid_price']
cocoprices=cocoprices[columns_to_keep]
couponprices=couponprices[columns_to_keep]
cocoprices = cocoprices.rename(columns={"mid_price": "price_coco"})
couponprices = couponprices.rename(columns={"mid_price": "price_coupon"})

# %%
cocoprices.to_excel("cocoprices.xlsx", sheet_name="Testing", index=False)
couponprices.to_excel("couponprices.xlsx", sheet_name="Testing", index=False)

# %%
df=pricesall[pricesall['product']=="COCONUT_COUPON"]

# %%
import matplotlib.pyplot as plt
plt.hist(df['mid_price'], bins=20, color='skyblue', edgecolor='black')
# Out:
# (array([ 108.,  130.,  740., 1898., 2311., 2556., 2032., 1466., 1024.,
#          921., 1767., 2103., 3525., 3345., 2725., 1545.,  771.,  551.,
#          328.,  154.]),
#  array([527.5, 538.2, 548.9, 559.6, 570.3, 581. , 591.7, 602.4, 613.1,
#         623.8, 634.5, 645.2, 655.9, 666.6, 677.3, 688. , 698.7, 709.4,
#         720.1, 730.8, 741.5]),
#  <BarContainer object of 20 artists>)
